# %%
"""
Created on Tue Aug 27 15:19:11 2024

@author: Thierry ALLEM

Applications d'algorithmes de Machine Learning supervisés dans le but de prévoir les niveaux d'échanges physiques (import/export d'électricité entres régions limitrophes)
en France métropolitaine sur la période 2020-2023.
L'échantillon d'entrainement est constitué des valeurs relevées sur la période 2013 à 2019.

J'ai testé et comparé 2 méthodologie de Machine Learning: 
-La première en utilisant les données sur l'ensemble des régions (modélisation"globale")
-La seconde en utilsant les données filtrées par région (mmodélisation "par segmentation")

"""
# Out:
# '\nCreated on Tue Aug 27 15:19:11 2024\n\n@author: Thierry ALLEM\n\nApplications d\'algorithmes de Machine Learning supervisés dans le but de prévoir les niveaux d\'échanges physiques (import/export d\'électricité entres régions limitrophes)\nen France métropolitaine sur la période 2020-2023.\nL\'échantillon d\'entrainement est constitué des valeurs relevées sur la période 2013 à 2019.\n\nJ\'ai testé et comparé 2 méthodologie de Machine Learning: \n-La première en utilisant les données sur l\'ensemble des régions (modélisation"globale")\n-La seconde en utilsant les données filtrées par région (mmodélisation "par segmentation")\n\n'

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from math import sqrt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, AdaBoostRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import xgboost as xgb
from xgboost import XGBRegressor
import warnings
warnings.filterwarnings('ignore')

# %%
# Importation du fichier eco2mix_regional_def préparé, incluant les TCO, TCH, cmax_rte et les populations régionales
# Lecture du fichier CSV
df_blackout_ml = pd.read_csv('df_blackout_ML_pop.csv', sep=';',low_memory=False)
# Lecture du fichier CSV
df_blackout_ml.head()
# Out:
#                 region           date_heure  annee  jour_numero     heure  \
# 0  CENTRE VAL DE LOIRE  2013-01-01 00:30:00   2013            1  00:30:00
# 1     PAYS DE LA LOIRE  2013-01-01 00:30:00   2013            1  00:30:00
# 2            GRAND EST  2013-01-01 00:30:00   2013            1  00:30:00
# 3        ILE DE FRANCE  2013-01-01 00:30:00   2013            1  00:30:00
# 4            OCCITANIE  2013-01-01 00:30:00   2013            1  00:30:00
#
#    jour_fractionnel  thermique  nucleaire  eolien  solaire  ...  \
# 0              1.02       90.0     9085.0   508.0      0.0  ...
# 1              1.02      127.0        0.0   182.0      0.0  ...
# 2              1.02      319.0     9137.0  1109.0      0.0  ...
# 3              1.02      685.0        0.0    16.0      0.0  ...
# 4              1.02       78.0     2497.0   367.0      0.0  ...
#
#    nucleaire_p_disp  eolien_p_disp  solaire_p_disp  cap_prod_max_hydraulique  \
# 0           11630.0          662.0           207.0                      91.0
# 1               0.0          454.0           385.0                       5.0
# 2           10820.0         1803.0           498.0                    2280.0
# 3               0.0           37.0           108.0                      19.0
# 4            2620.0          861.0          1040.0                    5368.0
#
#    ind_prod_hydraulique  hydraulique_p_disp  cap_prod_max_bioenergies  \
# 0                   0.0                91.0                      41.0
# 1                   0.0                 5.0                      57.0
# 2                   0.0              2280.0                      79.0
# 3                   0.0                19.0                     262.0
# 4                   0.0              5368.0                     126.0
#
#    bioenergies_p_disp  region_p_max  population
# 0                41.0       12788.0     2570548
# 1                57.0        2738.0     3660852
# 2                79.0       18878.0     5552388
# 3               262.0        2547.0    11959807
# 4               126.0       10260.0     5683878
#
# [5 rows x 29 columns]

# %%
df_blackout_ml.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2121396 entries, 0 to 2121395
# Data columns (total 29 columns):
#  #   Column                    Dtype
# ---  ------                    -----
#  0   region                    object
#  1   date_heure                object
#  2   annee                     int64
#  3   jour_numero               int64
#  4   heure                     object
#  5   jour_fractionnel          float64
#  6   thermique                 float64
#  7   nucleaire                 float64
#  8   eolien                    float64
#  9   solaire                   float64
#  10  hydraulique               float64
#  11  bioenergies               float64
#  12  pompage                   float64
#  13  ech_physiques             float64
#  14  stockage_batterie         float64
#  15  destockage_batterie       float64
#  16  cap_prod_max_thermique    float64
#  17  thermique_p_disp          float64
#  18  cap_prod_max_nucleaire    float64
#  19  nucleaire_p_disp          float64
#  20  eolien_p_disp             float64
#  21  solaire_p_disp            float64
#  22  cap_prod_max_hydraulique  float64
#  23  ind_prod_hydraulique      float64
#  24  hydraulique_p_disp        float64
#  25  cap_prod_max_bioenergies  float64
#  26  bioenergies_p_disp        float64
#  27  region_p_max              float64
#  28  population                int64
# dtypes: float64(23), int64(3), object(3)
# memory usage: 469.4+ MB

# %%
# Suppression des colonnes non nécessaires
col_to_drop = ['ind_prod_hydraulique','region_p_max']
df_blackout_ml = df_blackout_ml.drop(col_to_drop, axis=1)
df_blackout_ml.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2121396 entries, 0 to 2121395
# Data columns (total 27 columns):
#  #   Column                    Dtype
# ---  ------                    -----
#  0   region                    object
#  1   date_heure                object
#  2   annee                     int64
#  3   jour_numero               int64
#  4   heure                     object
#  5   jour_fractionnel          float64
#  6   thermique                 float64
#  7   nucleaire                 float64
#  8   eolien                    float64
#  9   solaire                   float64
#  10  hydraulique               float64
#  11  bioenergies               float64
#  12  pompage                   float64
#  13  ech_physiques             float64
#  14  stockage_batterie         float64
#  15  destockage_batterie       float64
#  16  cap_prod_max_thermique    float64
#  17  thermique_p_disp          float64
#  18  cap_prod_max_nucleaire    float64
#  19  nucleaire_p_disp          float64
#  20  eolien_p_disp             float64
#  21  solaire_p_disp            float64
#  22  cap_prod_max_hydraulique  float64
#  23  hydraulique_p_disp        float64
#  24  cap_prod_max_bioenergies  float64
#  25  bioenergies_p_disp        float64
#  26  population                int64
# dtypes: float64(21), int64(3), object(3)
# memory usage: 437.0+ MB

# %%
# Sélection de 10 000 lignes aléatoires
df_random_sample = df_blackout_ml.sample(n=10000, random_state=1)

# Exportation des données échantillonnées
df_random_sample.to_csv('sample_10000.csv', index=False)

# %%
# Filtrage des données pour les années 2013 à 2019 (les années 2020 à 2023 seront utilisées pour vérifier les prédictions)
df_blackout_ml_filtered = df_blackout_ml[(df_blackout_ml['annee'] >= 2013) & (df_blackout_ml['annee'] <= 2019)].copy()

# %%
# Conversion de la colonne 'date_heure' en datetime
df_blackout_ml_filtered['date_heure'] = pd.to_datetime(df_blackout_ml_filtered['date_heure'])

# Conversion de l'heure et des minutes en heure décimale
df_blackout_ml_filtered['heure_decimale'] = df_blackout_ml_filtered['date_heure'].dt.hour + df_blackout_ml_filtered['date_heure'].dt.minute / 60

# %%
# Encodages cycliques des données temporelles
df_blackout_ml_filtered['heure_decimale_sin'] = np.sin(2 * np.pi * df_blackout_ml_filtered['heure_decimale'] / 24)
df_blackout_ml_filtered['heure_decimale_cos'] = np.cos(2 * np.pi * df_blackout_ml_filtered['heure_decimale'] / 24)

# %%
# Fonction pour vérifier si une année est bissextile
def bissextile(annee):
    return annee % 4 == 0 and (annee % 100 != 0 or annee % 400 == 0)

# %%
# Ajout d'une colonne pour le nombre total de jours dans l'année en fonction de l'année
df_blackout_ml_filtered['total_jours_annee'] = df_blackout_ml_filtered['annee'].apply(
    lambda annee: 366 if bissextile(annee) else 365)

# %%
# Calcul des encodages cycliques en fonction du nombre de jours dans l'année
df_blackout_ml_filtered['jour_fractionnel_sin'] = np.sin(2 * np.pi * df_blackout_ml_filtered['jour_fractionnel'] / df_blackout_ml_filtered['total_jours_annee'])
df_blackout_ml_filtered['jour_fractionnel_cos'] = np.cos(2 * np.pi * df_blackout_ml_filtered['jour_fractionnel'] / df_blackout_ml_filtered['total_jours_annee'])

# %%
# Suppression de la colonne 'total_jours_annee'
df_blackout_ml_filtered = df_blackout_ml_filtered.drop('total_jours_annee', axis=1)

# %%
# Division des données en ensembles d'entraînement et de test
features = df_blackout_ml_filtered[['region', 'annee', 'jour_fractionnel_sin', 'jour_fractionnel_cos', 'heure_decimale_sin', 'heure_decimale_cos',
                                    'thermique', 'nucleaire', 'eolien', 'solaire', 'hydraulique', 'bioenergies',
                                    'pompage', 'stockage_batterie', 'destockage_batterie', 'cap_prod_max_thermique','thermique_p_disp',
                                    'cap_prod_max_nucleaire', 'nucleaire_p_disp','cap_prod_max_hydraulique', 'hydraulique_p_disp',
                                    'cap_prod_max_bioenergies','bioenergies_p_disp',
                                    'solaire_p_disp', 'eolien_p_disp', 'population']]

target = df_blackout_ml_filtered['ech_physiques']

# %%
# Encodage des variables catégorielles (comme 'region')
features = pd.get_dummies(features, columns=['region'])

# %%
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

# %%
# Standardisation des données
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

features.head()
# Out:
#    annee  jour_fractionnel_sin  jour_fractionnel_cos  heure_decimale_sin  \
# 0   2013              0.017558              0.999846            0.130526
# 1   2013              0.017558              0.999846            0.130526
# 2   2013              0.017558              0.999846            0.130526
# 3   2013              0.017558              0.999846            0.130526
# 4   2013              0.017558              0.999846            0.130526
#
#    heure_decimale_cos  thermique  nucleaire  eolien  solaire  hydraulique  \
# 0            0.991445       90.0     9085.0   508.0      0.0         34.0
# 1            0.991445      127.0        0.0   182.0      0.0          0.0
# 2            0.991445      319.0     9137.0  1109.0      0.0       1418.0
# 3            0.991445      685.0        0.0    16.0      0.0          0.0
# 4            0.991445       78.0     2497.0   367.0      0.0        943.0
#
#    ...  region_BRETAGNE  region_CENTRE VAL DE LOIRE  region_GRAND EST  \
# 0  ...            False                        True             False
# 1  ...            False                       False             False
# 2  ...            False                       False              True
# 3  ...            False                       False             False
# 4  ...            False                       False             False
#
#    region_HAUTS DE FRANCE  region_ILE DE FRANCE  region_NORMANDIE  \
# 0                   False                 False             False
# 1                   False                 False             False
# 2                   False                 False             False
# 3                   False                  True             False
# 4                   False                 False             False
#
#    region_NOUVELLE AQUITAINE  region_OCCITANIE  region_PAYS DE LA LOIRE  \
# 0                      False             False                    False
# 1                      False             False                     True
# 2                      False             False                    False
# 3                      False             False                    False
# 4                      False              True                    False
#
#    region_PROVENCE ALPES COTE D AZUR
# 0                              False
# 1                              False
# 2                              False
# 3                              False
# 4                              False
#
# [5 rows x 37 columns]

# %%
# MACHINE LEARNING GLOBAL 

# Initialisation des modèles
models = {
    "Random Forest": RandomForestRegressor(n_estimators=30, random_state=42,n_jobs=None),
    "Linear Regression": LinearRegression(),
    "Ridge Regression": Ridge(),
    "Lasso Regression": Lasso(),
    "ElasticNet Regression": ElasticNet(),
    "Decision Tree": DecisionTreeRegressor(),    
    "Gradient Boosting": GradientBoostingRegressor(n_estimators=50, random_state=42), 
    "AdaBoost": AdaBoostRegressor(n_estimators=60, random_state=42),
    "XGBoost": xgb.XGBRegressor(n_estimators=60, random_state=42)
}

from tqdm import tqdm

# Création d'un DataFrame pour stocker les résultats
results = pd.DataFrame(columns=['Model', 'MSE', 'RMSE', 'MAE', 'R2', 'Train Score', 'Test Score'])

# Entraînement et évaluation des modèles

for name, model in models.items() :
    print (f"Entraînement du modèle {name}...")
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)

    # Calcul des métriques
    mse = mean_squared_error(y_test, y_pred)
    rmse = sqrt(mse)
    mae = mean_absolute_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)
    train_score = model.score(X_train, y_train)
    test_score = model.score(X_test, y_test)
    
# Création d'un DataFrame temporaire pour la nouvelle ligne de résultats
    new_result = pd.DataFrame({
        'Model': [name], 
        'MSE': [mse], 
        'RMSE': [rmse], 
        'MAE': [mae], 
        'R2': [r2],
        'Train Score': [train_score],
        'Test Score': [test_score]
    })
    
    # Ajout des résultats
    results = pd.concat([results, new_result], ignore_index=True)
    # Affichage des résultats pour chaque modèle
    print(f"Modèle {name} terminé. MSE : {mse:.4f}, RMSE: {rmse:.4f},  MAE : {mae : .4f}, R2: {r2:.4f}, Train Score: {train_score:.4f},Test Score: {test_score : .4f}")
    
print("Tous les modèles ont été évalués.")
# Out:
# Entraînement du modèle Random Forest...
# Modèle Random Forest terminé. MSE : 32755.7956, RMSE: 180.9856,  MAE :  123.7252, R2: 0.9983, Train Score: 0.9997,Test Score:  0.9983
# Entraînement du modèle Linear Regression...
# Modèle Linear Regression terminé. MSE : 471451.9821, RMSE: 686.6236,  MAE :  496.1775, R2: 0.9760, Train Score: 0.9763,Test Score:  0.9760
# Entraînement du modèle Ridge Regression...
# Modèle Ridge Regression terminé. MSE : 471452.8942, RMSE: 686.6243,  MAE :  496.1770, R2: 0.9760, Train Score: 0.9763,Test Score:  0.9760
# Entraînement du modèle Lasso Regression...
# Modèle Lasso Regression terminé. MSE : 473994.8921, RMSE: 688.4729,  MAE :  497.1765, R2: 0.9759, Train Score: 0.9762,Test Score:  0.9759
# Entraînement du modèle ElasticNet Regression...
# Modèle ElasticNet Regression terminé. MSE : 1247036.4773, RMSE: 1116.7079,  MAE :  818.3569, R2: 0.9366, Train Score: 0.9368,Test Score:  0.9366
# Entraînement du modèle Decision Tree...
# Modèle Decision Tree terminé. MSE : 73564.7694, RMSE: 271.2283,  MAE :  167.4846, R2: 0.9963, Train Score: 1.0000,Test Score:  0.9963
# Entraînement du modèle Gradient Boosting...
# Modèle Gradient Boosting terminé. MSE : 469274.9702, RMSE: 685.0365,  MAE :  517.3514, R2: 0.9762, Train Score: 0.9764,Test Score:  0.9762
# Entraînement du modèle AdaBoost...
# Modèle AdaBoost terminé. MSE : 704066.9171, RMSE: 839.0870,  MAE :  664.0324, R2: 0.9642, Train Score: 0.9643,Test Score:  0.9642
# Entraînement du modèle XGBoost...
# Modèle XGBoost terminé. MSE : 145295.6771, RMSE: 381.1767,  MAE :  286.1276, R2: 0.9926, Train Score: 0.9927,Test Score:  0.9926
# Tous les modèles ont été évalués.

# %%
# Exportation des résultats dans un fichier Excel
results.to_excel("models_ech_phys_results.xlsx", index=False, engine='openpyxl')

# %%
# MODELISATION PAR SEGMENTATION (Par région)

# Initialisation des modèles
models = {
    "Random Forest": RandomForestRegressor(n_estimators=30, random_state=42, n_jobs=1),
    "Linear Regression": LinearRegression(),
    "Ridge Regression": Ridge(),
    "Lasso Regression": Lasso(),
    "ElasticNet Regression": ElasticNet(),
    "Decision Tree": DecisionTreeRegressor(),    
    "Gradient Boosting": GradientBoostingRegressor(n_estimators=50, random_state=42), 
    "AdaBoost": AdaBoostRegressor(n_estimators=60, random_state=42),
    "XGBoost": xgb.XGBRegressor(n_estimators=60, random_state=42)
}

# Liste des régions uniques
regions = df_blackout_ml_filtered['region'].unique()

# Dictionnaire pour stocker les résultats par région
results_by_region = {}

# Entraînement et évaluation des modèles par région
for region in regions:
    # Filtrage des données pour la région actuelle
    df_region = df_blackout_ml_filtered[df_blackout_ml_filtered['region'] == region].copy()
    
    # Séparation des variables explicatives de la cible
    features = df_region[['annee', 'jour_fractionnel_sin', 'jour_fractionnel_cos', 'heure_decimale_sin', 'heure_decimale_cos',
                          'thermique', 'nucleaire', 'eolien', 'solaire', 'hydraulique', 'bioenergies',
                          'pompage', 'stockage_batterie', 'destockage_batterie', 'cap_prod_max_thermique','thermique_p_disp',
                          'cap_prod_max_nucleaire', 'nucleaire_p_disp', 'cap_prod_max_hydraulique', 'hydraulique_p_disp',
                          'cap_prod_max_bioenergies','bioenergies_p_disp',
                          'solaire_p_disp', 'eolien_p_disp', 'population']]
    
    target = df_region['ech_physiques']
    
    # Encodage des variables catégorielles (comme 'region') - ici, 'region' est déjà filtré
    features = pd.get_dummies(features)
    
    # Division des données en ensembles d'entraînement et de test
    X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)
    
    # Standardisation des données
    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train)
    X_test = scaler.transform(X_test)
    
    # Création d'un DataFrame pour stocker les résultats pour cette région
    results = pd.DataFrame(columns=['Model', 'MSE', 'RMSE', 'MAE', 'R2', 'Train Score', 'Test Score'])
    
    # Entraînement et évaluation des modèles
    for name, model in models.items():
        print(f"Entraînement du modèle {name} pour la région {region}...")  # Affiche le nom du modèle en cours
        model.fit(X_train, y_train)
        y_pred = model.predict(X_test)

        # Calcul des métriques
        mse = mean_squared_error(y_test, y_pred)
        rmse = sqrt(mse)
        mae = mean_absolute_error(y_test, y_pred)
        r2 = r2_score(y_test, y_pred)
        train_score = model.score(X_train, y_train)
        test_score = model.score(X_test, y_test)
        
        # Création d'un DataFrame temporaire pour la nouvelle ligne de résultats
        new_result = pd.DataFrame({
            'Model': [name], 
            'MSE': [mse], 
            'RMSE': [rmse], 
            'MAE': [mae], 
            'R2': [r2],
            'Train Score': [train_score],
            'Test Score': [test_score]
        })
        
        # Ajout des résultats
        results = pd.concat([results, new_result], ignore_index=True)
        # Affichage des résultats pour chaque modèle
        print(f"Modèle {name} terminé pour la région {region}. MSE : {mse:.4f}, RMSE: {rmse:.4f},  MAE : {mae:.4f}, R2: {r2:.4f}, Train Score: {train_score:.4f}, Test Score: {test_score:.4f}")
    
    # Stockage des résultats dans le dictionnaire
    results_by_region[region] = results
    
    # Exportation des résultats pour chaque région dans un fichier Excel
    results.to_excel(f"models_ech_phys_results_{region}.xlsx", index=False, engine='openpyxl')

print("Tous les modèles ont été évalués pour chaque région.")
# Out:
# Entraînement du modèle Random Forest pour la région CENTRE VAL DE LOIRE...
# Modèle Random Forest terminé pour la région CENTRE VAL DE LOIRE. MSE : 10363.2149, RMSE: 101.7999,  MAE : 74.5194, R2: 0.9957, Train Score: 0.9993, Test Score: 0.9957
# Entraînement du modèle Linear Regression pour la région CENTRE VAL DE LOIRE...
# Modèle Linear Regression terminé pour la région CENTRE VAL DE LOIRE. MSE : 80058.2231, RMSE: 282.9456,  MAE : 222.3356, R2: 0.9670, Train Score: 0.9669, Test Score: 0.9670
# Entraînement du modèle Ridge Regression pour la région CENTRE VAL DE LOIRE...
# Modèle Ridge Regression terminé pour la région CENTRE VAL DE LOIRE. MSE : 80058.0667, RMSE: 282.9453,  MAE : 222.3356, R2: 0.9670, Train Score: 0.9669, Test Score: 0.9670
# Entraînement du modèle Lasso Regression pour la région CENTRE VAL DE LOIRE...
# Modèle Lasso Regression terminé pour la région CENTRE VAL DE LOIRE. MSE : 80181.5080, RMSE: 283.1634,  MAE : 222.5635, R2: 0.9670, Train Score: 0.9669, Test Score: 0.9670
# Entraînement du modèle ElasticNet Regression pour la région CENTRE VAL DE LOIRE...
# Modèle ElasticNet Regression terminé pour la région CENTRE VAL DE LOIRE. MSE : 364323.2654, RMSE: 603.5920,  MAE : 481.7439, R2: 0.8499, Train Score: 0.8485, Test Score: 0.8499
# Entraînement du modèle Decision Tree pour la région CENTRE VAL DE LOIRE...
# Modèle Decision Tree terminé pour la région CENTRE VAL DE LOIRE. MSE : 23997.3422, RMSE: 154.9108,  MAE : 102.5773, R2: 0.9901, Train Score: 1.0000, Test Score: 0.9901
# Entraînement du modèle Gradient Boosting pour la région CENTRE VAL DE LOIRE...
# Modèle Gradient Boosting terminé pour la région CENTRE VAL DE LOIRE. MSE : 73835.6357, RMSE: 271.7271,  MAE : 214.1486, R2: 0.9696, Train Score: 0.9700, Test Score: 0.9696
# Entraînement du modèle AdaBoost pour la région CENTRE VAL DE LOIRE...
# Modèle AdaBoost terminé pour la région CENTRE VAL DE LOIRE. MSE : 116712.3862, RMSE: 341.6319,  MAE : 275.6166, R2: 0.9519, Train Score: 0.9526, Test Score: 0.9519
# Entraînement du modèle XGBoost pour la région CENTRE VAL DE LOIRE...
# Modèle XGBoost terminé pour la région CENTRE VAL DE LOIRE. MSE : 23080.3864, RMSE: 151.9223,  MAE : 117.1707, R2: 0.9905, Train Score: 0.9916, Test Score: 0.9905
# Entraînement du modèle Random Forest pour la région PAYS DE LA LOIRE...
# Modèle Random Forest terminé pour la région PAYS DE LA LOIRE. MSE : 20949.6058, RMSE: 144.7398,  MAE : 103.6249, R2: 0.9423, Train Score: 0.9906, Test Score: 0.9423
# Entraînement du modèle Linear Regression pour la région PAYS DE LA LOIRE...
# Modèle Linear Regression terminé pour la région PAYS DE LA LOIRE. MSE : 198323.3653, RMSE: 445.3351,  MAE : 357.8685, R2: 0.4534, Train Score: 0.4575, Test Score: 0.4534
# Entraînement du modèle Ridge Regression pour la région PAYS DE LA LOIRE...
# Modèle Ridge Regression terminé pour la région PAYS DE LA LOIRE. MSE : 198320.4890, RMSE: 445.3319,  MAE : 357.8676, R2: 0.4534, Train Score: 0.4575, Test Score: 0.4534
# Entraînement du modèle Lasso Regression pour la région PAYS DE LA LOIRE...
# Modèle Lasso Regression terminé pour la région PAYS DE LA LOIRE. MSE : 199519.2452, RMSE: 446.6758,  MAE : 358.9503, R2: 0.4501, Train Score: 0.4535, Test Score: 0.4501
# Entraînement du modèle ElasticNet Regression pour la région PAYS DE LA LOIRE...
# Modèle ElasticNet Regression terminé pour la région PAYS DE LA LOIRE. MSE : 231787.3953, RMSE: 481.4430,  MAE : 383.8590, R2: 0.3612, Train Score: 0.3591, Test Score: 0.3612
# Entraînement du modèle Decision Tree pour la région PAYS DE LA LOIRE...
# Modèle Decision Tree terminé pour la région PAYS DE LA LOIRE. MSE : 48922.5927, RMSE: 221.1845,  MAE : 135.1563, R2: 0.8652, Train Score: 1.0000, Test Score: 0.8652
# Entraînement du modèle Gradient Boosting pour la région PAYS DE LA LOIRE...
# Modèle Gradient Boosting terminé pour la région PAYS DE LA LOIRE. MSE : 135251.7302, RMSE: 367.7659,  MAE : 289.8738, R2: 0.6272, Train Score: 0.6304, Test Score: 0.6272
# Entraînement du modèle AdaBoost pour la région PAYS DE LA LOIRE...
# Modèle AdaBoost terminé pour la région PAYS DE LA LOIRE. MSE : 169629.7961, RMSE: 411.8614,  MAE : 336.2825, R2: 0.5325, Train Score: 0.5323, Test Score: 0.5325
# Entraînement du modèle XGBoost pour la région PAYS DE LA LOIRE...
# Modèle XGBoost terminé pour la région PAYS DE LA LOIRE. MSE : 54000.7653, RMSE: 232.3806,  MAE : 178.1680, R2: 0.8512, Train Score: 0.8654, Test Score: 0.8512
# Entraînement du modèle Random Forest pour la région GRAND EST...
# Modèle Random Forest terminé pour la région GRAND EST. MSE : 28496.6824, RMSE: 168.8096,  MAE : 126.5336, R2: 0.9904, Train Score: 0.9984, Test Score: 0.9904
# Entraînement du modèle Linear Regression pour la région GRAND EST...
# Modèle Linear Regression terminé pour la région GRAND EST. MSE : 159601.2024, RMSE: 399.5012,  MAE : 318.6316, R2: 0.9461, Train Score: 0.9470, Test Score: 0.9461
# Entraînement du modèle Ridge Regression pour la région GRAND EST...
# Modèle Ridge Regression terminé pour la région GRAND EST. MSE : 159601.6343, RMSE: 399.5017,  MAE : 318.6320, R2: 0.9461, Train Score: 0.9470, Test Score: 0.9461
# Entraînement du modèle Lasso Regression pour la région GRAND EST...
# Modèle Lasso Regression terminé pour la région GRAND EST. MSE : 160040.6544, RMSE: 400.0508,  MAE : 319.1502, R2: 0.9459, Train Score: 0.9468, Test Score: 0.9459
# Entraînement du modèle ElasticNet Regression pour la région GRAND EST...
# Modèle ElasticNet Regression terminé pour la région GRAND EST. MSE : 519716.0378, RMSE: 720.9133,  MAE : 572.4863, R2: 0.8243, Train Score: 0.8263, Test Score: 0.8243
# Entraînement du modèle Decision Tree pour la région GRAND EST...
# Modèle Decision Tree terminé pour la région GRAND EST. MSE : 68372.7828, RMSE: 261.4819,  MAE : 181.8845, R2: 0.9769, Train Score: 1.0000, Test Score: 0.9769
# Entraînement du modèle Gradient Boosting pour la région GRAND EST...
# Modèle Gradient Boosting terminé pour la région GRAND EST. MSE : 198637.5769, RMSE: 445.6878,  MAE : 355.4486, R2: 0.9329, Train Score: 0.9341, Test Score: 0.9329
# Entraînement du modèle AdaBoost pour la région GRAND EST...
# Modèle AdaBoost terminé pour la région GRAND EST. MSE : 290857.6674, RMSE: 539.3122,  MAE : 436.8112, R2: 0.9017, Train Score: 0.9037, Test Score: 0.9017
# Entraînement du modèle XGBoost pour la région GRAND EST...
# Modèle XGBoost terminé pour la région GRAND EST. MSE : 64933.5511, RMSE: 254.8206,  MAE : 201.4998, R2: 0.9781, Train Score: 0.9806, Test Score: 0.9781
# Entraînement du modèle Random Forest pour la région ILE DE FRANCE...
# Modèle Random Forest terminé pour la région ILE DE FRANCE. MSE : 92257.4423, RMSE: 303.7391,  MAE : 204.0527, R2: 0.9749, Train Score: 0.9960, Test Score: 0.9749
# Entraînement du modèle Linear Regression pour la région ILE DE FRANCE...
# Modèle Linear Regression terminé pour la région ILE DE FRANCE. MSE : 909296.2780, RMSE: 953.5703,  MAE : 760.5756, R2: 0.7531, Train Score: 0.7481, Test Score: 0.7531
# Entraînement du modèle Ridge Regression pour la région ILE DE FRANCE...
# Modèle Ridge Regression terminé pour la région ILE DE FRANCE. MSE : 909299.6099, RMSE: 953.5720,  MAE : 760.5758, R2: 0.7531, Train Score: 0.7481, Test Score: 0.7531
# Entraînement du modèle Lasso Regression pour la région ILE DE FRANCE...
# Modèle Lasso Regression terminé pour la région ILE DE FRANCE. MSE : 911528.9905, RMSE: 954.7403,  MAE : 761.4128, R2: 0.7525, Train Score: 0.7476, Test Score: 0.7525
# Entraînement du modèle ElasticNet Regression pour la région ILE DE FRANCE...
# Modèle ElasticNet Regression terminé pour la région ILE DE FRANCE. MSE : 1123019.5398, RMSE: 1059.7262,  MAE : 852.7376, R2: 0.6950, Train Score: 0.6905, Test Score: 0.6950
# Entraînement du modèle Decision Tree pour la région ILE DE FRANCE...
# Modèle Decision Tree terminé pour la région ILE DE FRANCE. MSE : 192988.7754, RMSE: 439.3049,  MAE : 263.3423, R2: 0.9476, Train Score: 1.0000, Test Score: 0.9476
# Entraînement du modèle Gradient Boosting pour la région ILE DE FRANCE...
# Modèle Gradient Boosting terminé pour la région ILE DE FRANCE. MSE : 567187.5865, RMSE: 753.1186,  MAE : 586.9647, R2: 0.8460, Train Score: 0.8441, Test Score: 0.8460
# Entraînement du modèle AdaBoost pour la région ILE DE FRANCE...
# Modèle AdaBoost terminé pour la région ILE DE FRANCE. MSE : 812519.8846, RMSE: 901.3988,  MAE : 743.5035, R2: 0.7793, Train Score: 0.7765, Test Score: 0.7793
# Entraînement du modèle XGBoost pour la région ILE DE FRANCE...
# Modèle XGBoost terminé pour la région ILE DE FRANCE. MSE : 212921.7474, RMSE: 461.4344,  MAE : 349.0833, R2: 0.9422, Train Score: 0.9468, Test Score: 0.9422
# Entraînement du modèle Random Forest pour la région OCCITANIE...
# Modèle Random Forest terminé pour la région OCCITANIE. MSE : 34437.5974, RMSE: 185.5737,  MAE : 135.5677, R2: 0.9668, Train Score: 0.9948, Test Score: 0.9668
# Entraînement du modèle Linear Regression pour la région OCCITANIE...
# Modèle Linear Regression terminé pour la région OCCITANIE. MSE : 268799.0253, RMSE: 518.4583,  MAE : 409.3156, R2: 0.7409, Train Score: 0.7404, Test Score: 0.7409
# Entraînement du modèle Ridge Regression pour la région OCCITANIE...
# Modèle Ridge Regression terminé pour la région OCCITANIE. MSE : 268801.4278, RMSE: 518.4606,  MAE : 409.3129, R2: 0.7409, Train Score: 0.7404, Test Score: 0.7409
# Entraînement du modèle Lasso Regression pour la région OCCITANIE...
# Modèle Lasso Regression terminé pour la région OCCITANIE. MSE : 269769.6587, RMSE: 519.3935,  MAE : 409.8273, R2: 0.7400, Train Score: 0.7396, Test Score: 0.7400
# Entraînement du modèle ElasticNet Regression pour la région OCCITANIE...
# Modèle ElasticNet Regression terminé pour la région OCCITANIE. MSE : 390384.9487, RMSE: 624.8079,  MAE : 494.5583, R2: 0.6237, Train Score: 0.6233, Test Score: 0.6237
# Entraînement du modèle Decision Tree pour la région OCCITANIE...
# Modèle Decision Tree terminé pour la région OCCITANIE. MSE : 81639.2444, RMSE: 285.7258,  MAE : 191.3945, R2: 0.9213, Train Score: 1.0000, Test Score: 0.9213
# Entraînement du modèle Gradient Boosting pour la région OCCITANIE...
# Modèle Gradient Boosting terminé pour la région OCCITANIE. MSE : 184689.3055, RMSE: 429.7549,  MAE : 333.6606, R2: 0.8220, Train Score: 0.8233, Test Score: 0.8220
# Entraînement du modèle AdaBoost pour la région OCCITANIE...
# Modèle AdaBoost terminé pour la région OCCITANIE. MSE : 243102.7848, RMSE: 493.0545,  MAE : 393.7138, R2: 0.7657, Train Score: 0.7669, Test Score: 0.7657
# Entraînement du modèle XGBoost pour la région OCCITANIE...
# Modèle XGBoost terminé pour la région OCCITANIE. MSE : 55122.2171, RMSE: 234.7812,  MAE : 182.0831, R2: 0.9469, Train Score: 0.9534, Test Score: 0.9469
# Entraînement du modèle Random Forest pour la région NORMANDIE...
# Modèle Random Forest terminé pour la région NORMANDIE. MSE : 12541.6222, RMSE: 111.9894,  MAE : 81.0425, R2: 0.9949, Train Score: 0.9992, Test Score: 0.9949
# Entraînement du modèle Linear Regression pour la région NORMANDIE...
# Modèle Linear Regression terminé pour la région NORMANDIE. MSE : 126362.8080, RMSE: 355.4755,  MAE : 282.3565, R2: 0.9486, Train Score: 0.9493, Test Score: 0.9486
# Entraînement du modèle Ridge Regression pour la région NORMANDIE...
# Modèle Ridge Regression terminé pour la région NORMANDIE. MSE : 126362.6211, RMSE: 355.4752,  MAE : 282.3562, R2: 0.9486, Train Score: 0.9493, Test Score: 0.9486
# Entraînement du modèle Lasso Regression pour la région NORMANDIE...
# Modèle Lasso Regression terminé pour la région NORMANDIE. MSE : 126617.7265, RMSE: 355.8338,  MAE : 282.6006, R2: 0.9485, Train Score: 0.9492, Test Score: 0.9485
# Entraînement du modèle ElasticNet Regression pour la région NORMANDIE...
# Modèle ElasticNet Regression terminé pour la région NORMANDIE. MSE : 466775.2402, RMSE: 683.2095,  MAE : 547.1964, R2: 0.8102, Train Score: 0.8118, Test Score: 0.8102
# Entraînement du modèle Decision Tree pour la région NORMANDIE...
# Modèle Decision Tree terminé pour la région NORMANDIE. MSE : 28552.0192, RMSE: 168.9734,  MAE : 111.2227, R2: 0.9884, Train Score: 1.0000, Test Score: 0.9884
# Entraînement du modèle Gradient Boosting pour la région NORMANDIE...
# Modèle Gradient Boosting terminé pour la région NORMANDIE. MSE : 112287.1675, RMSE: 335.0928,  MAE : 263.4360, R2: 0.9543, Train Score: 0.9552, Test Score: 0.9543
# Entraînement du modèle AdaBoost pour la région NORMANDIE...
# Modèle AdaBoost terminé pour la région NORMANDIE. MSE : 192744.1839, RMSE: 439.0264,  MAE : 352.9330, R2: 0.9216, Train Score: 0.9238, Test Score: 0.9216
# Entraînement du modèle XGBoost pour la région NORMANDIE...
# Modèle XGBoost terminé pour la région NORMANDIE. MSE : 29775.7057, RMSE: 172.5564,  MAE : 132.8888, R2: 0.9879, Train Score: 0.9894, Test Score: 0.9879
# Entraînement du modèle Random Forest pour la région PROVENCE ALPES COTE D AZUR...
# Modèle Random Forest terminé pour la région PROVENCE ALPES COTE D AZUR. MSE : 19121.7520, RMSE: 138.2814,  MAE : 100.7650, R2: 0.9747, Train Score: 0.9959, Test Score: 0.9747
# Entraînement du modèle Linear Regression pour la région PROVENCE ALPES COTE D AZUR...
# Modèle Linear Regression terminé pour la région PROVENCE ALPES COTE D AZUR. MSE : 287767.8186, RMSE: 536.4399,  MAE : 432.1709, R2: 0.6194, Train Score: 0.6208, Test Score: 0.6194
# Entraînement du modèle Ridge Regression pour la région PROVENCE ALPES COTE D AZUR...
# Modèle Ridge Regression terminé pour la région PROVENCE ALPES COTE D AZUR. MSE : 287771.7758, RMSE: 536.4436,  MAE : 432.1805, R2: 0.6194, Train Score: 0.6208, Test Score: 0.6194
# Entraînement du modèle Lasso Regression pour la région PROVENCE ALPES COTE D AZUR...
# Modèle Lasso Regression terminé pour la région PROVENCE ALPES COTE D AZUR. MSE : 288654.5014, RMSE: 537.2658,  MAE : 433.5575, R2: 0.6182, Train Score: 0.6199, Test Score: 0.6182
# Entraînement du modèle ElasticNet Regression pour la région PROVENCE ALPES COTE D AZUR...
# Modèle ElasticNet Regression terminé pour la région PROVENCE ALPES COTE D AZUR. MSE : 385968.4404, RMSE: 621.2636,  MAE : 504.8215, R2: 0.4895, Train Score: 0.4884, Test Score: 0.4895
# Entraînement du modèle Decision Tree pour la région PROVENCE ALPES COTE D AZUR...
# Modèle Decision Tree terminé pour la région PROVENCE ALPES COTE D AZUR. MSE : 43566.6175, RMSE: 208.7262,  MAE : 140.5109, R2: 0.9424, Train Score: 1.0000, Test Score: 0.9424
# Entraînement du modèle Gradient Boosting pour la région PROVENCE ALPES COTE D AZUR...
# Modèle Gradient Boosting terminé pour la région PROVENCE ALPES COTE D AZUR. MSE : 149384.3073, RMSE: 386.5027,  MAE : 304.9224, R2: 0.8024, Train Score: 0.8063, Test Score: 0.8024
# Entraînement du modèle AdaBoost pour la région PROVENCE ALPES COTE D AZUR...
# Modèle AdaBoost terminé pour la région PROVENCE ALPES COTE D AZUR. MSE : 191325.8231, RMSE: 437.4081,  MAE : 354.9231, R2: 0.7470, Train Score: 0.7484, Test Score: 0.7470
# Entraînement du modèle XGBoost pour la région PROVENCE ALPES COTE D AZUR...
# Modèle XGBoost terminé pour la région PROVENCE ALPES COTE D AZUR. MSE : 39501.4518, RMSE: 198.7497,  MAE : 152.8828, R2: 0.9478, Train Score: 0.9536, Test Score: 0.9478
# Entraînement du modèle Random Forest pour la région BOURGOGNE FRANCHE COMTE...
# Modèle Random Forest terminé pour la région BOURGOGNE FRANCHE COMTE. MSE : 10970.2585, RMSE: 104.7390,  MAE : 74.2989, R2: 0.9543, Train Score: 0.9923, Test Score: 0.9543
# Entraînement du modèle Linear Regression pour la région BOURGOGNE FRANCHE COMTE...
# Modèle Linear Regression terminé pour la région BOURGOGNE FRANCHE COMTE. MSE : 98267.6386, RMSE: 313.4767,  MAE : 252.6945, R2: 0.5907, Train Score: 0.5855, Test Score: 0.5907
# Entraînement du modèle Ridge Regression pour la région BOURGOGNE FRANCHE COMTE...
# Modèle Ridge Regression terminé pour la région BOURGOGNE FRANCHE COMTE. MSE : 98267.7290, RMSE: 313.4768,  MAE : 252.6946, R2: 0.5907, Train Score: 0.5855, Test Score: 0.5907
# Entraînement du modèle Lasso Regression pour la région BOURGOGNE FRANCHE COMTE...
# Modèle Lasso Regression terminé pour la région BOURGOGNE FRANCHE COMTE. MSE : 98661.6032, RMSE: 314.1044,  MAE : 253.2415, R2: 0.5890, Train Score: 0.5839, Test Score: 0.5890
# Entraînement du modèle ElasticNet Regression pour la région BOURGOGNE FRANCHE COMTE...
# Modèle ElasticNet Regression terminé pour la région BOURGOGNE FRANCHE COMTE. MSE : 115064.9399, RMSE: 339.2122,  MAE : 273.4455, R2: 0.5207, Train Score: 0.5154, Test Score: 0.5207
# Entraînement du modèle Decision Tree pour la région BOURGOGNE FRANCHE COMTE...
# Modèle Decision Tree terminé pour la région BOURGOGNE FRANCHE COMTE. MSE : 24888.4310, RMSE: 157.7607,  MAE : 93.0917, R2: 0.8963, Train Score: 1.0000, Test Score: 0.8963
# Entraînement du modèle Gradient Boosting pour la région BOURGOGNE FRANCHE COMTE...
# Modèle Gradient Boosting terminé pour la région BOURGOGNE FRANCHE COMTE. MSE : 73729.2919, RMSE: 271.5314,  MAE : 217.8666, R2: 0.6929, Train Score: 0.6911, Test Score: 0.6929
# Entraînement du modèle AdaBoost pour la région BOURGOGNE FRANCHE COMTE...
# Modèle AdaBoost terminé pour la région BOURGOGNE FRANCHE COMTE. MSE : 90799.9127, RMSE: 301.3302,  MAE : 249.3040, R2: 0.6218, Train Score: 0.6161, Test Score: 0.6218
# Entraînement du modèle XGBoost pour la région BOURGOGNE FRANCHE COMTE...
# Modèle XGBoost terminé pour la région BOURGOGNE FRANCHE COMTE. MSE : 33200.1456, RMSE: 182.2091,  MAE : 141.6185, R2: 0.8617, Train Score: 0.8706, Test Score: 0.8617
# Entraînement du modèle Random Forest pour la région HAUTS DE FRANCE...
# Modèle Random Forest terminé pour la région HAUTS DE FRANCE. MSE : 31276.0385, RMSE: 176.8503,  MAE : 130.0333, R2: 0.9726, Train Score: 0.9957, Test Score: 0.9726
# Entraînement du modèle Linear Regression pour la région HAUTS DE FRANCE...
# Modèle Linear Regression terminé pour la région HAUTS DE FRANCE. MSE : 257816.7283, RMSE: 507.7566,  MAE : 406.5385, R2: 0.7744, Train Score: 0.7786, Test Score: 0.7744
# Entraînement du modèle Ridge Regression pour la région HAUTS DE FRANCE...
# Modèle Ridge Regression terminé pour la région HAUTS DE FRANCE. MSE : 257817.1509, RMSE: 507.7570,  MAE : 406.5384, R2: 0.7744, Train Score: 0.7786, Test Score: 0.7744
# Entraînement du modèle Lasso Regression pour la région HAUTS DE FRANCE...
# Modèle Lasso Regression terminé pour la région HAUTS DE FRANCE. MSE : 258177.5673, RMSE: 508.1118,  MAE : 406.7132, R2: 0.7741, Train Score: 0.7784, Test Score: 0.7741
# Entraînement du modèle ElasticNet Regression pour la région HAUTS DE FRANCE...
# Modèle ElasticNet Regression terminé pour la région HAUTS DE FRANCE. MSE : 398912.8241, RMSE: 631.5955,  MAE : 506.2602, R2: 0.6509, Train Score: 0.6568, Test Score: 0.6509
# Entraînement du modèle Decision Tree pour la région HAUTS DE FRANCE...
# Modèle Decision Tree terminé pour la région HAUTS DE FRANCE. MSE : 71633.7673, RMSE: 267.6449,  MAE : 178.8471, R2: 0.9373, Train Score: 1.0000, Test Score: 0.9373
# Entraînement du modèle Gradient Boosting pour la région HAUTS DE FRANCE...
# Modèle Gradient Boosting terminé pour la région HAUTS DE FRANCE. MSE : 228636.5349, RMSE: 478.1595,  MAE : 381.7102, R2: 0.7999, Train Score: 0.8050, Test Score: 0.7999
# Entraînement du modèle AdaBoost pour la région HAUTS DE FRANCE...
# Modèle AdaBoost terminé pour la région HAUTS DE FRANCE. MSE : 307891.5697, RMSE: 554.8798,  MAE : 450.6237, R2: 0.7306, Train Score: 0.7367, Test Score: 0.7306
# Entraînement du modèle XGBoost pour la région HAUTS DE FRANCE...
# Modèle XGBoost terminé pour la région HAUTS DE FRANCE. MSE : 70512.7189, RMSE: 265.5423,  MAE : 205.8669, R2: 0.9383, Train Score: 0.9443, Test Score: 0.9383
# Entraînement du modèle Random Forest pour la région BRETAGNE...
# Modèle Random Forest terminé pour la région BRETAGNE. MSE : 25008.0661, RMSE: 158.1394,  MAE : 116.1409, R2: 0.9332, Train Score: 0.9893, Test Score: 0.9332
# Entraînement du modèle Linear Regression pour la région BRETAGNE...
# Modèle Linear Regression terminé pour la région BRETAGNE. MSE : 140370.9948, RMSE: 374.6612,  MAE : 301.3064, R2: 0.6253, Train Score: 0.6233, Test Score: 0.6253
# Entraînement du modèle Ridge Regression pour la région BRETAGNE...
# Modèle Ridge Regression terminé pour la région BRETAGNE. MSE : 140372.3680, RMSE: 374.6630,  MAE : 301.3055, R2: 0.6253, Train Score: 0.6233, Test Score: 0.6253
# Entraînement du modèle Lasso Regression pour la région BRETAGNE...
# Modèle Lasso Regression terminé pour la région BRETAGNE. MSE : 141173.3139, RMSE: 375.7304,  MAE : 302.1137, R2: 0.6231, Train Score: 0.6215, Test Score: 0.6231
# Entraînement du modèle ElasticNet Regression pour la région BRETAGNE...
# Modèle ElasticNet Regression terminé pour la région BRETAGNE. MSE : 170450.9066, RMSE: 412.8570,  MAE : 330.3092, R2: 0.5450, Train Score: 0.5465, Test Score: 0.5450
# Entraînement du modèle Decision Tree pour la région BRETAGNE...
# Modèle Decision Tree terminé pour la région BRETAGNE. MSE : 53918.0200, RMSE: 232.2025,  MAE : 147.7436, R2: 0.8561, Train Score: 1.0000, Test Score: 0.8561
# Entraînement du modèle Gradient Boosting pour la région BRETAGNE...
# Modèle Gradient Boosting terminé pour la région BRETAGNE. MSE : 103253.6483, RMSE: 321.3311,  MAE : 254.2079, R2: 0.7244, Train Score: 0.7237, Test Score: 0.7244
# Entraînement du modèle AdaBoost pour la région BRETAGNE...
# Modèle AdaBoost terminé pour la région BRETAGNE. MSE : 128360.9583, RMSE: 358.2750,  MAE : 294.7838, R2: 0.6573, Train Score: 0.6553, Test Score: 0.6573
# Entraînement du modèle XGBoost pour la région BRETAGNE...
# Modèle XGBoost terminé pour la région BRETAGNE. MSE : 43655.3354, RMSE: 208.9386,  MAE : 161.7247, R2: 0.8835, Train Score: 0.8926, Test Score: 0.8835
# Entraînement du modèle Random Forest pour la région AUVERGNE RHONE ALPES...
# Modèle Random Forest terminé pour la région AUVERGNE RHONE ALPES. MSE : 69784.4960, RMSE: 264.1676,  MAE : 194.0182, R2: 0.9841, Train Score: 0.9975, Test Score: 0.9841
# Entraînement du modèle Linear Regression pour la région AUVERGNE RHONE ALPES...
# Modèle Linear Regression terminé pour la région AUVERGNE RHONE ALPES. MSE : 371892.4482, RMSE: 609.8299,  MAE : 485.7889, R2: 0.9152, Train Score: 0.9153, Test Score: 0.9152
# Entraînement du modèle Ridge Regression pour la région AUVERGNE RHONE ALPES...
# Modèle Ridge Regression terminé pour la région AUVERGNE RHONE ALPES. MSE : 371894.1200, RMSE: 609.8312,  MAE : 485.7881, R2: 0.9152, Train Score: 0.9153, Test Score: 0.9152
# Entraînement du modèle Lasso Regression pour la région AUVERGNE RHONE ALPES...
# Modèle Lasso Regression terminé pour la région AUVERGNE RHONE ALPES. MSE : 372506.2816, RMSE: 610.3329,  MAE : 486.2049, R2: 0.9150, Train Score: 0.9151, Test Score: 0.9150
# Entraînement du modèle ElasticNet Regression pour la région AUVERGNE RHONE ALPES...
# Modèle ElasticNet Regression terminé pour la région AUVERGNE RHONE ALPES. MSE : 859996.4623, RMSE: 927.3599,  MAE : 739.3878, R2: 0.8039, Train Score: 0.8029, Test Score: 0.8039
# Entraînement du modèle Decision Tree pour la région AUVERGNE RHONE ALPES...
# Modèle Decision Tree terminé pour la région AUVERGNE RHONE ALPES. MSE : 171945.4792, RMSE: 414.6631,  MAE : 285.3996, R2: 0.9608, Train Score: 1.0000, Test Score: 0.9608
# Entraînement du modèle Gradient Boosting pour la région AUVERGNE RHONE ALPES...
# Modèle Gradient Boosting terminé pour la région AUVERGNE RHONE ALPES. MSE : 378651.8630, RMSE: 615.3469,  MAE : 485.7842, R2: 0.9136, Train Score: 0.9141, Test Score: 0.9136
# Entraînement du modèle AdaBoost pour la région AUVERGNE RHONE ALPES...
# Modèle AdaBoost terminé pour la région AUVERGNE RHONE ALPES. MSE : 626265.5203, RMSE: 791.3694,  MAE : 640.4328, R2: 0.8572, Train Score: 0.8582, Test Score: 0.8572
# Entraînement du modèle XGBoost pour la région AUVERGNE RHONE ALPES...
# Modèle XGBoost terminé pour la région AUVERGNE RHONE ALPES. MSE : 123760.3143, RMSE: 351.7958,  MAE : 275.8221, R2: 0.9718, Train Score: 0.9751, Test Score: 0.9718
# Entraînement du modèle Random Forest pour la région NOUVELLE AQUITAINE...
# Modèle Random Forest terminé pour la région NOUVELLE AQUITAINE. MSE : 27932.0447, RMSE: 167.1288,  MAE : 124.1400, R2: 0.9774, Train Score: 0.9963, Test Score: 0.9774
# Entraînement du modèle Linear Regression pour la région NOUVELLE AQUITAINE...
# Modèle Linear Regression terminé pour la région NOUVELLE AQUITAINE. MSE : 365370.1128, RMSE: 604.4585,  MAE : 473.9478, R2: 0.7048, Train Score: 0.7056, Test Score: 0.7048
# Entraînement du modèle Ridge Regression pour la région NOUVELLE AQUITAINE...
# Modèle Ridge Regression terminé pour la région NOUVELLE AQUITAINE. MSE : 365365.7664, RMSE: 604.4549,  MAE : 473.9361, R2: 0.7048, Train Score: 0.7056, Test Score: 0.7048
# Entraînement du modèle Lasso Regression pour la région NOUVELLE AQUITAINE...
# Modèle Lasso Regression terminé pour la région NOUVELLE AQUITAINE. MSE : 365893.6332, RMSE: 604.8914,  MAE : 473.8736, R2: 0.7044, Train Score: 0.7051, Test Score: 0.7044
# Entraînement du modèle ElasticNet Regression pour la région NOUVELLE AQUITAINE...
# Modèle ElasticNet Regression terminé pour la région NOUVELLE AQUITAINE. MSE : 535234.8517, RMSE: 731.5975,  MAE : 578.7002, R2: 0.5676, Train Score: 0.5675, Test Score: 0.5676
# Entraînement du modèle Decision Tree pour la région NOUVELLE AQUITAINE...
# Modèle Decision Tree terminé pour la région NOUVELLE AQUITAINE. MSE : 63981.7721, RMSE: 252.9462,  MAE : 170.7070, R2: 0.9483, Train Score: 1.0000, Test Score: 0.9483
# Entraînement du modèle Gradient Boosting pour la région NOUVELLE AQUITAINE...
# Modèle Gradient Boosting terminé pour la région NOUVELLE AQUITAINE. MSE : 257721.8284, RMSE: 507.6631,  MAE : 394.9743, R2: 0.7918, Train Score: 0.7932, Test Score: 0.7918
# Entraînement du modèle AdaBoost pour la région NOUVELLE AQUITAINE...
# Modèle AdaBoost terminé pour la région NOUVELLE AQUITAINE. MSE : 328386.0755, RMSE: 573.0498,  MAE : 458.1573, R2: 0.7347, Train Score: 0.7352, Test Score: 0.7347
# Entraînement du modèle XGBoost pour la région NOUVELLE AQUITAINE...
# Modèle XGBoost terminé pour la région NOUVELLE AQUITAINE. MSE : 76013.9949, RMSE: 275.7064,  MAE : 213.0453, R2: 0.9386, Train Score: 0.9448, Test Score: 0.9386
# Tous les modèles ont été évalués pour chaque région.
